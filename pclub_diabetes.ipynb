# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import pickle
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
dia = pd.read_csv("Datasets/diabetes2.csv", index_col=0)
dia
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# ...

# %%
from sklearn.model_selection import train_test_split
X = dia.drop(["Outcome"], axis=1)
y = dia["Outcome"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
y_logistic_pred = clf.predict(X_test)
print(classification_report(y_test, y_logistic_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82        99
#            1       0.68      0.65      0.67        55
#
#     accuracy                           0.77       154
#    macro avg       0.75      0.74      0.74       154
# weighted avg       0.76      0.77      0.77       154

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
gd = make_pipeline(StandardScaler(), SGDClassifier(max_iter=1000, tol=1e-3))
gd.fit(X_train, y_train)
gd_pred = gd.predict(X_test)
print(classification_report(y_test, gd_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        99
#            1       0.54      0.71      0.61        55
#
#     accuracy                           0.68       154
#    macro avg       0.67      0.69      0.67       154
# weighted avg       0.71      0.68      0.69       154
